# %% [markdown]
# ### Automatic English class test creator
#
# This notebook automatically generates English class test using examples from site: https://www.gettinenglish.com
#
# Students names are read from file: uczniowie.txt
#
# Test are different for every student and are saved in separate folder with names in files.
#
# Separate files with answers are generated.
#
# (Should be customizable, changing webpage should only demand finding proper tag on webpage.)

# %%
import random, os, bs4, requests
from string import Template

# %%
def delete_polish_signs(text):
    d = {"ą":"a","ę":"e","ł":"l","ś":"s","ć":"c","ż":"z","ź":"z","ń":"n","ó":"o"}
    return "".join([d[c] if c in d.keys() else c for c in text])

# %%
def get_tasks(urls, tag, task_out_sep, task_in_sep, reverse = False):
    """
    Parser do url-i.
    Pobieramy adresy URL oraz tagi i zapisujemu polecenia do słownika:
        key: pytanie
        value: odpowiedź
    Proces jest ujednolicony przez co trochę mało optymalnie pewne rzeczy są.
    Najpierw szukamy kontenerów z przykładami.
    Rozdzielamy kontener na przypadki
    Rozdizelamy na pytanie i odpowiedź
    
    Takie działanie sprawdza się w przypadku strony z zadaniami z angielskiego, na której testuje.
    Na innych stronach ciężej pewnie będzię z określeniem separatorów jeśli struktura będzie inna.
    """
    result = {}
    if type(urls) != list:
        urls = [urls]
    for url in urls:
        req = requests.get(url, headers={'User-Agent': 'Chrome'})
        req.encoding = 'utf-8'
        req.raise_for_status()
        soup = bs4.BeautifulSoup(req.text,'html.parser')
        
        temp = soup.body
        temp = temp.find_all(attrs = {tag[0]:tag[1]})
        for task_pack in temp:
            tasks = [task_pack]
            if '<' not in task_out_sep:
                tasks = task_pack.get_text().split(task_out_sep)
            else:
                tasks = task_pack.find_all(task_out_sep.replace('<','').replace('>',''))
                tasks = [task.get_text() for task in tasks]
                
            for task in tasks:
                try:
                    eng, pol = task.split(task_in_sep)
                    if reverse:
                        result[eng] = pol
                    else:
                        result[pol] = eng
                except:
                    pass
    return result

# %%
def random_tasks(n, dic, desc, sep):
    """
    Funkcja generuje tekst skryptu LateX-owego w formacie
    Opis polecenia
        -losowy podpunkt
        -losowy podpunkt
        -...
    Generuje zarówno polecenie, jak i polecenie z odpowiedzią.
    W zwizku z tym że i tak mamy tu dostęp do obu informacji.
    """
    if sep =='\n':
        sep = r'\\'
    else:
        sep = r'\quad'+sep+r'\quad'
    tasks = []
    anwsers = []
    for i in range(n):
        word = random.choice(list(dic.keys()))
        tasks.append("\item " + word + sep)
        anwsers.append("\item " + word + sep + "{\color{red}" + dic[word]+'}')
    
    tasks = '\n'.join(f'{z}' for i, z in enumerate(tasks, 1))
    anwsers = '\n'.join(f'{z}' for i, z in enumerate(anwsers, 1))
    
    tasks = desc + '\n\\begin{enumerate}\n' + tasks + '\n\\end{enumerate}\n'
    anwsers = desc + '\n\\begin{enumerate}\n' + anwsers + '\n\\end{enumerate}\n'
    return tasks, anwsers

# %%
exam_template = r'''
\documentclass{article}
\usepackage[T1]{fontenc}
\usepackage[utf8]{inputenc}
\usepackage{lmodern}
\usepackage{textcomp}
\usepackage{lastpage}
\usepackage{amsmath}
\usepackage{xcolor}

\begin{document}
\normalsize
${STUDENT}
\section*{Kartkówka Angielski}
${ZADANIE}
Rozwiązania odeślij na mail: anowak@ok.pl do godziny 16:00.
A. Nowak
\end{document}
'''

# %%
def create_exam(folder_name, file_name, students_list_path, exam_template, task_list):
    """
    Function generates final LaTex files.
    It generates test and anwser files in separate path.
    
    :param str folder_name: folder name to save the result in
    :param str file_name: core file name for results
    :param str student_list_path: path to students list
    :param raw str exam_template: LaTex template, to avoid errors raw strings are recommended
    :param list of dict task_list:
    """
    tt = Template(exam_template)
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    tasks_bases = []
    for task in task_list:
        tasks_bases.append(get_tasks(task['urls'], task['tag'], task['out_sep'], task['in_sep'], task['reverse']))

    with open(students_list_path,"r") as file:
        names = file.readlines()
        for name in names:
            imie, nazwisko = name.split(" ")
            imie, nazwisko = delete_polish_signs(imie.strip()),delete_polish_signs(nazwisko.strip())
            with open(folder_name+"/"+file_name+"_"+nazwisko+"_"+imie+".tex","w") as outfile,\
                open(folder_name+"/"+file_name+"_"+nazwisko+"_"+imie+"_odp.tex","w") as anwserfile:
                zads = ''
                odps = ''
                for i in range(len(task_list)):
                    zad, odp = random_tasks(5, tasks_bases[i], task_list[i]['desc'], sep = task_list[i]['in_sep'])
                    zads += zad
                    odps += odp
                
                outtext = tt.substitute(STUDENT = nazwisko +" "+ imie, ZADANIE = zads)
                outfile.write(outtext)
                
                outtext = tt.substitute(STUDENT = nazwisko +" "+ imie, ZADANIE = odps)
                anwserfile.write(outtext)

# %%
########################
# Parametry które można zmienić
########################
strony_ze_slowami=['https://www.gettinenglish.com/angielskie-slownictwo-z-prasy/',
                    'https://www.gettinenglish.com/sporty-zimowe-angielskie-slownictwo/',
                    'https://www.gettinenglish.com/angielskie-wyrazenia-zwiazane-z-pieniedzmi/',
                    'https://www.gettinenglish.com/angielskie-slownictwo-zwiazane-z-terroryzmem/']

strony_ze_zdaniami = ['https://www.gettinenglish.com/present-simple/',
                     'https://www.gettinenglish.com/present-continuous/',
                     'https://www.gettinenglish.com/present-perfect/',
                     'https://www.gettinenglish.com/present-perfect-continuous/',
                     'https://www.gettinenglish.com/past-simple-2/',
                     'https://www.gettinenglish.com/past-continuous/',
                     'https://www.gettinenglish.com/past-perfect/',
                     'https://www.gettinenglish.com/past-perfect-continuous/',
                     'https://www.gettinenglish.com/future-simple/',
                     'https://www.gettinenglish.com/future-continuous/',
                     'https://www.gettinenglish.com/future-perfect/',
                     'https://www.gettinenglish.com/future-perfect-continuous/',
                     'https://www.gettinenglish.com/be-going-to/']

# Najważnieszy parametr, musimy dla każdego zadania sprecyzować parametry.
# Robiłem to z myślą o stronie gettinenglish.
# Na niej artykuły pisane są w ten sposób że pare przykładów zapisanych jest pod jednym tagiem

# desc    - polecenie które jest niezmienne dla każdego ucznia
# urls    - ulr, bądź lista url-i skąd mamy pobrać treści podpunktów(muszą być tej samej sruktury, odnosić się do tych samych tagów)
# tag     - tag który pozwala znaleź kontener z przykładami
# out_sep - separator przykładów wewnątrz kontenera(dla słów jest to \n, dla zdań każdy jest w osobnym tagu listowym <li>
#           ale żeby było bardziej uniwersalnie to podaje że separatorem jest <li>, w kodzie uzywam wtedy find_all drugi raz)
# in_sep  - separator części napisanej po polsku, a części angielskiej
# reverse - Czy ma być tłumaczenie z polskiego na angielski czy na odwrót
task_list = [
    {'desc':'Zad.1. Przetłumacz następujące słowa na polski',
     'urls':strony_ze_slowami,
     'tag':('class','col-xs-6 bs-shortcode-col'),
     'out_sep':'\n',
     'in_sep':'–',
     'reverse': False},
    {'desc':'Zad.2. Przetłumacz następujące słowa na angielski',
     'urls':strony_ze_slowami,
     'tag':('class','col-xs-6 bs-shortcode-col'),
     'out_sep':'\n',
     'in_sep':'–',
     'reverse': True},
    {'desc':'Zad.3. Przetłumacz zdania na angielski',
     'urls':strony_ze_zdaniami,
     'tag':('class','bs-shortcode-list list-style-edit'),
     'out_sep':'<li>',
     'in_sep':'\n',
     'reverse': False}
]

# %%
create_exam('test','test_nr_1_english','data/uczniowie.txt',exam_template,task_list)

# %% [markdown]
# ### Compiling LaTex files and deleting leftover files

# %%
# %%bash
# cd test
# for i in *.tex; do pdflatex $i; done
# rm *.aux
# rm *.tex
# rm *.log
# cd ..
# Out:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Dabrowski_Stanislaw_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Dabrowski_Stanislaw_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Dabrowski_Stanislaw_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Dabrowski_Stanislaw_odp.pdf (1 page, 57464
# bytes).
# Transcript written on test_nr_1_english_Dabrowski_Stanislaw_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Dabrowski_Stanislaw.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Dabrowski_Stanislaw.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Dabrowski_Stanislaw.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Dabrowski_Stanislaw.pdf (1 page, 55981 byte
# s).
# Transcript written on test_nr_1_english_Dabrowski_Stanislaw.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Grabowski_Antoni_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Grabowski_Antoni_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Grabowski_Antoni_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Grabowski_Antoni_odp.pdf (1 page, 58393 byt
# es).
# Transcript written on test_nr_1_english_Grabowski_Antoni_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Grabowski_Antoni.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Grabowski_Antoni.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Grabowski_Antoni.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Grabowski_Antoni.pdf (1 page, 56624 bytes).
# Transcript written on test_nr_1_english_Grabowski_Antoni.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Jankowski_Filip_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Jankowski_Filip_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Jankowski_Filip_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Jankowski_Filip_odp.pdf (1 page, 58525 byte
# s).
# Transcript written on test_nr_1_english_Jankowski_Filip_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Jankowski_Filip.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Jankowski_Filip.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Jankowski_Filip.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Jankowski_Filip.pdf (1 page, 56323 bytes).
# Transcript written on test_nr_1_english_Jankowski_Filip.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kaczmarek_Aleksander_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kaczmarek_Aleksander_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kaczmarek_Aleksander_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kaczmarek_Aleksander_odp.pdf (1 page, 58076
#  bytes).
# Transcript written on test_nr_1_english_Kaczmarek_Aleksander_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kaczmarek_Aleksander.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kaczmarek_Aleksander.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kaczmarek_Aleksander.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kaczmarek_Aleksander.pdf (1 page, 56363 byt
# es).
# Transcript written on test_nr_1_english_Kaczmarek_Aleksander.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kaczmarek_Jan_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kaczmarek_Jan_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kaczmarek_Jan_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kaczmarek_Jan_odp.pdf (1 page, 58919 bytes)
# .
# Transcript written on test_nr_1_english_Kaczmarek_Jan_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kaczmarek_Jan.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kaczmarek_Jan.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kaczmarek_Jan.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kaczmarek_Jan.pdf (1 page, 56676 bytes).
# Transcript written on test_nr_1_english_Kaczmarek_Jan.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kaminska_Maria_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kaminska_Maria_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kaminska_Maria_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kaminska_Maria_odp.pdf (1 page, 57857 bytes
# ).
# Transcript written on test_nr_1_english_Kaminska_Maria_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kaminska_Maria.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kaminska_Maria.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kaminska_Maria.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kaminska_Maria.pdf (1 page, 56186 bytes).
# Transcript written on test_nr_1_english_Kaminska_Maria.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kowalczyk_Pola_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kowalczyk_Pola_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kowalczyk_Pola_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kowalczyk_Pola_odp.pdf (1 page, 58001 bytes
# ).
# Transcript written on test_nr_1_english_Kowalczyk_Pola_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kowalczyk_Pola.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kowalczyk_Pola.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kowalczyk_Pola.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kowalczyk_Pola.pdf (1 page, 56196 bytes).
# Transcript written on test_nr_1_english_Kowalczyk_Pola.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kowalska_Antonina_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kowalska_Antonina_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kowalska_Antonina_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kowalska_Antonina_odp.pdf (1 page, 58281 by
# tes).
# Transcript written on test_nr_1_english_Kowalska_Antonina_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kowalska_Antonina.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kowalska_Antonina.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kowalska_Antonina.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kowalska_Antonina.pdf (1 page, 57275 bytes)
# .
# Transcript written on test_nr_1_english_Kowalska_Antonina.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kozlowski_Leon_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kozlowski_Leon_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kozlowski_Leon_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kozlowski_Leon_odp.pdf (1 page, 57920 bytes
# ).
# Transcript written on test_nr_1_english_Kozlowski_Leon_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kozlowski_Leon.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kozlowski_Leon.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kozlowski_Leon.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kozlowski_Leon.pdf (1 page, 56152 bytes).
# Transcript written on test_nr_1_english_Kozlowski_Leon.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kwiatkowski_Franciszek_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kwiatkowski_Franciszek_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kwiatkowski_Franciszek_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kwiatkowski_Franciszek_odp.pdf (1 page, 583
# 51 bytes).
# Transcript written on test_nr_1_english_Kwiatkowski_Franciszek_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Kwiatkowski_Franciszek.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Kwiatkowski_Franciszek.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Kwiatkowski_Franciszek.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Kwiatkowski_Franciszek.pdf (1 page, 57008 b
# ytes).
# Transcript written on test_nr_1_english_Kwiatkowski_Franciszek.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Lewandowska_Laura_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# ...
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Wojciechowski_Szymon.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Wojciechowski_Szymon.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Wojciechowski_Szymon.pdf (1 page, 56303 byt
# es).
# Transcript written on test_nr_1_english_Wojciechowski_Szymon.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Wojcik_Amelia_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Wojcik_Amelia_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Wojcik_Amelia_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Wojcik_Amelia_odp.pdf (1 page, 57093 bytes)
# .
# Transcript written on test_nr_1_english_Wojcik_Amelia_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Wojcik_Amelia.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Wojcik_Amelia.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Wojcik_Amelia.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Wojcik_Amelia.pdf (1 page, 55796 bytes).
# Transcript written on test_nr_1_english_Wojcik_Amelia.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Wozniak_Lena_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Wozniak_Lena_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Wozniak_Lena_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Wozniak_Lena_odp.pdf (1 page, 57687 bytes).
# Transcript written on test_nr_1_english_Wozniak_Lena_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Wozniak_Lena.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Wozniak_Lena.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Wozniak_Lena.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Wozniak_Lena.pdf (1 page, 56459 bytes).
# Transcript written on test_nr_1_english_Wozniak_Lena.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Zielinska_Oliwia_odp.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Zielinska_Oliwia_odp.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Zielinska_Oliwia_odp.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  ){/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/
# public/lm/lmbx12.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Zielinska_Oliwia_odp.pdf (1 page, 58502 byt
# es).
# Transcript written on test_nr_1_english_Zielinska_Oliwia_odp.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./test_nr_1_english_Zielinska_Oliwia.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file test_nr_1_english_Zielinska_Oliwia.aux.
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# Underfull \hbox (badness 10000) in paragraph at lines 33--34
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 34--35
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 35--36
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 36--37
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 37--38
#
#
# Package lastpage Warning: Rerun to get the references right on input line 42.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# (./test_nr_1_english_Zielinska_Oliwia.aux)
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-ec.enc}</usr/share/texmf/fonts/type1/public/lm/lmbx12.pfb></usr/sh
# are/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on test_nr_1_english_Zielinska_Oliwia.pdf (1 page, 57403 bytes).
# Transcript written on test_nr_1_english_Zielinska_Oliwia.log.
